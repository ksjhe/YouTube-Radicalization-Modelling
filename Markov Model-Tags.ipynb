# %% [markdown]
# # Markov Model Design
# This code reads in each one of the datasets created by our webscraper and concatenates them into one large data frame. The data frame is then normalized for each origin category to create a markov simulation

# %%
import time
import pandas as pd
import numpy as np
import scipy.linalg as la
import random
np.set_printoptions(suppress=True)
pd.set_option('display.float_format', lambda x: '%.10f' % x)

# %%
#sets an ideology per channel
ideology = pd.read_csv("Hard Tagged Channels.csv")
ideology = ideology[ideology[["CHANNEL_TITLE","IDEOLOGY"]] != np.nan][["CHANNEL_TITLE","IDEOLOGY"]]
ideology['IDEOLOGY'].value_counts()
# Out:
# IDW                        128
# Alt-light                   97
# Social Justice              84
# Conspiracy                  80
# Partisan Right              52
# Partisan Left               52
# Alt-right                   44
# Libertarian                 36
# Socialist                   36
# Anti-Theist                 29
# MRA                         18
# Religious Conservative      13
# Revolutionary Socialist     10
# Anti-white                   3
# Name: IDEOLOGY, dtype: int64

# %%
#creates the Markov Probability matrix
test = pd.read_csv("combined tags.csv").drop(columns = "Unnamed: 0")

#sets categories for current channel
test = test.rename({"Category":"Current Tag"}, axis = 1)

#sets categories into Next channel and removes others
test = test.rename({"TAGS":"Next Tag"}, axis = 1)[["Current Tag","Next Tag","Count","Current Views"]].fillna("Others")
test = test.rename({"Count":"Amount"}, axis = 1)
test = test[test["Next Tag"] != "Others"].reset_index().drop(columns = "index")

#creates the impiressions
test["Impressions"] = test["Current Views"]*test["Amount"]
test = test.drop(columns = ["Amount","Current Views"]).groupby(['Current Tag','Next Tag']).sum().reset_index()
test
# Out:
#            Current Tag           Next Tag         Impressions
# 0              AntiSJW                AIN   106360.0000000000
# 1              AntiSJW            AntiSJW 10415722.0000000000
# 2              AntiSJW         AntiTheist  3891964.0000000000
# 3              AntiSJW         Conspiracy 34311090.0000000000
# 4              AntiSJW        Educational   323834.0000000000
# ..                 ...                ...                 ...
# 288  WhiteIdentitarian      SocialJustice   827871.0000000000
# 289  WhiteIdentitarian          Socialist     2896.0000000000
# 290  WhiteIdentitarian        StateFunded  1381317.0000000000
# 291  WhiteIdentitarian                 TV  1641450.0000000000
# 292  WhiteIdentitarian  WhiteIdentitarian  2290388.0000000000
#
# [293 rows x 3 columns]

# %%
test = pd.merge(test,test.groupby("Current Tag")['Impressions'].sum(), how = "left",left_on = "Current Tag",right_on = "Current Tag")
test["Probability"] = test["Impressions_x"]/test["Impressions_y"]
test = test.drop(columns = ["Impressions_x","Impressions_y"])
test
# Out:
#            Current Tag           Next Tag  Probability
# 0              AntiSJW                AIN 0.0014016091
# 1              AntiSJW            AntiSJW 0.1372580918
# 2              AntiSJW         AntiTheist 0.0512881922
# 3              AntiSJW         Conspiracy 0.4521505798
# 4              AntiSJW        Educational 0.0042674754
# ..                 ...                ...          ...
# 288  WhiteIdentitarian      SocialJustice 0.0287083236
# 289  WhiteIdentitarian          Socialist 0.0001004254
# 290  WhiteIdentitarian        StateFunded 0.0479003316
# 291  WhiteIdentitarian                 TV 0.0569210394
# 292  WhiteIdentitarian  WhiteIdentitarian 0.0794244513
#
# [293 rows x 3 columns]

# %%
#Creates the Markov Matrix
#test = test.groupby(["Current Ideology","Next Ideology"]).sum().reset_index()
topics = test["Current Tag"].unique()
markovmatrix = pd.DataFrame()
for topic in topics:
    temp = test[test["Current Tag"] == topic].transpose().rename(columns = test["Next Tag"], index = {"Probability":topic}).iloc[2:]
    markovmatrix = markovmatrix.append(temp)
markovmatrix = markovmatrix.fillna(0)
markovmatrix = markovmatrix.reindex(sorted(markovmatrix.columns),axis = 1)#.drop(index = "Others")
markovmatrix
#markovmatrix.to_csv("Markov Matrix without Others.csv")
# Out:
#                                AIN      AntiSJW   AntiTheist  AntiWhiteness  \
# AntiSJW               0.0014016091 0.1372580918 0.0512881922   0.0000000000
# AntiTheist            0.0080047647 0.0833488749 0.7963373549   0.0000000000
# AntiWhiteness         0.0000000000 0.0000000000 0.0000000000   0.2118056464
# Conspiracy            0.0040147342 0.0003268456 0.0000000000   0.0000000000
# Educational           0.0000909056 0.0004990516 0.0014553655   0.0000000000
# LateNightTalkShow     0.0000000000 0.0000000000 0.0000000000   0.0000000000
# Libertarian           0.0013307468 0.0251094262 0.0000000000   0.0000000000
# MRA                   0.0019448455 0.2270318809 0.0000000000   0.0000000000
# Mainstream News       0.0000000000 0.0000000000 0.0000000000   0.0301806102
# ManoelAltLite         0.0193210336 0.0908549821 0.0000000000   0.0014885410
# ManoelAltRight        0.0249990295 0.2325330206 0.0000000000   0.0000000000
# MissingLinkMedia      0.0000000000 0.0004593843 0.0000000000   0.0000000000
# PartisanLeft          0.0000000000 0.0000000000 0.0000000000   0.0000212485
# PartisanRight         0.0331163398 0.1198770336 0.0000000000   0.0038462246
# Provocateur           0.0283780639 0.2150503091 0.0000000000   0.0146699980
# ReligiousConservative 0.0032844339 0.2401552266 0.0000000000   0.0000000000
# SocialJustice         0.0000000000 0.0001080318 0.0003142985   0.0000000000
# Socialist             0.0015417361 0.0547480031 0.0000000000   0.0000000000
# StateFunded           0.0000000000 0.0000000000 0.0000000000   0.0000000000
# WhiteIdentitarian     0.0054374686 0.1013378984 0.0000000000   0.0000000000
#
#                         Conspiracy  Educational  LateNightTalkShow  \
# AntiSJW               0.4521505798 0.0042674754       0.0000000000
# AntiTheist            0.0050694681 0.0277694575       0.0000000000
# AntiWhiteness         0.0000000000 0.0000000000       0.0159428343
# Conspiracy            0.2229290553 0.0003451866       0.0000000000
# Educational           0.0000000000 0.6818954334       0.0220970286
# LateNightTalkShow     0.0000000000 0.0000000000       0.2784218630
# Libertarian           0.0000000000 0.0002441013       0.0000000000
# MRA                   0.0303702672 0.0143658510       0.0036164145
# Mainstream News       0.0000000000 0.0083285488       0.0136719441
# ManoelAltLite         0.0108322886 0.0008699354       0.0013865920
# ManoelAltRight        0.0033307623 0.0004057420       0.0000000000
# MissingLinkMedia      0.0000000000 0.1230384139       0.0000000000
# PartisanLeft          0.0065124193 0.0008951098       0.0398390447
# PartisanRight         0.0045645875 0.0000221058       0.0042560887
# Provocateur           0.0895055700 0.0087034725       0.0068340686
# ReligiousConservative 0.0055455669 0.0005319899       0.0000000000
# SocialJustice         0.0000000000 0.0318007397       0.0469736901
# Socialist             0.0004788383 0.0343583674       0.0000498275
# StateFunded           0.0009717254 0.0035370891       0.0000000000
# WhiteIdentitarian     0.0212885970 0.0022943883       0.0000000000
#
#                        Libertarian          MRA  Mainstream News  ...  \
# AntiSJW               0.0518215179 0.0010885664     0.0697111946  ...
# AntiTheist            0.0000727076 0.0000000000     0.0001932979  ...
# AntiWhiteness         0.0000000000 0.0000000000     0.1379129752  ...
# Conspiracy            0.3304095934 0.0000000000     0.0945153482  ...
# Educational           0.0000567240 0.0000000000     0.0114996658  ...
# LateNightTalkShow     0.0000000000 0.0000000000     0.0047266134  ...
# Libertarian           0.4598733047 0.0000000000     0.0856667050  ...
# MRA                   0.1157349073 0.1647571612     0.0785778611  ...
# Mainstream News       0.0000000000 0.0000000000     0.4266383478  ...
# ManoelAltLite         0.1521380561 0.0000000000     0.0765270833  ...
# ManoelAltRight        0.3343842244 0.0000000000     0.0322977326  ...
# MissingLinkMedia      0.0190427621 0.0000000000     0.0670078449  ...
# PartisanLeft          0.0018045563 0.0000000000     0.0212820648  ...
# PartisanRight         0.1394853528 0.0000000000     0.0725456457  ...
# Provocateur           0.1835886276 0.0000000000     0.0454821998  ...
# ReligiousConservative 0.1828915187 0.0000000000     0.0823045518  ...
# SocialJustice         0.0000483801 0.0000000000     0.0228951759  ...
# Socialist             0.0105032187 0.0000000000     0.0019577989  ...
# StateFunded           0.0022244933 0.0000000000     0.2655982797  ...
# WhiteIdentitarian     0.4369969105 0.0000000000     0.1044845505  ...
#
#                        PartisanLeft  PartisanRight  Provocateur  \
# AntiSJW                0.0025960605   0.1024481891 0.0005867756
# AntiTheist             0.0161082024   0.0028737490 0.0000000000
# AntiWhiteness          0.1453893887   0.0540372788 0.1536744519
# Conspiracy             0.0047203327   0.1828735950 0.0008446255
# Educational            0.0107384734   0.0003236447 0.0000000000
# LateNightTalkShow      0.2440216832   0.0000549812 0.0000000000
# Libertarian            0.0168246025   0.2118844571 0.0000000000
# MRA                    0.0606133898   0.0338590401 0.0000000000
# Mainstream News        0.0502707526   0.0424939492 0.0000000000
# ManoelAltLite          0.0293640663   0.2444200702 0.0001712920
# ManoelAltRight         0.0001305684   0.1260458622 0.0000000000
# MissingLinkMedia       0.0390926105   0.1092044898 0.0000000000
# PartisanLeft           0.5469397423   0.0041652736 0.0000000000
# PartisanRight          0.0175808070   0.4209419008 0.0099415247
# Provocateur            0.0161534692   0.0883949663 0.1353204198
# ReligiousConservative  0.0027967961   0.0687676868 0.0000000000
# SocialJustice          0.0619895959   0.0041374693 0.0000000000
# Socialist              0.0610090960   0.0016031722 0.0286159093
# StateFunded            0.2118808551   0.0375592957 0.0000000000
# WhiteIdentitarian      0.0056680032   0.0539632052 0.0000000000
#
#                        ReligiousConservative  Revolutionary  SocialJustice  \
# AntiSJW                         0.0118906422   0.0000000000   0.0024400860
# AntiTheist                      0.0005652672   0.0000000000   0.0076673936
# AntiWhiteness                   0.0000000000   0.0000000000   0.0855831950
# Conspiracy                      0.0037325065   0.0000000000   0.0368669519
# Educational                     0.0001334135   0.0000000000   0.0115277152
# LateNightTalkShow               0.0000000000   0.0000000000   0.2896217117
# Libertarian                     0.0075825092   0.0000000000   0.0000578560
# MRA                             0.0211065041   0.0000000000   0.0721693348
# Mainstream News                 0.0000000000   0.0000000000   0.0390032816
# ManoelAltLite                   0.0113319269   0.0000000000   0.0826193717
# ManoelAltRight                  0.0054526600   0.0000000000   0.0219147998
# MissingLinkMedia                0.0206169223   0.0000000000   0.1428022339
# PartisanLeft                    0.0000000000   0.0000000000   0.0176094343
# PartisanRight                   0.0038653254   0.0000000000   0.0079694109
# Provocateur                     0.0000000000   0.0000000000   0.0135000902
# ReligiousConservative           0.0962389439   0.0000000000   0.0894069336
# SocialJustice                   0.0000000000   0.0000000000   0.6911453051
# Socialist                       0.0145646378   0.0086556714   0.5430790467
# StateFunded                     0.0000000000   0.0000000000   0.0051178462
# WhiteIdentitarian               0.0205831569   0.0000000000   0.0287083236
#
#                          Socialist  StateFunded           TV  \
# AntiSJW               0.0000000000 0.0011521105 0.0321226243
# AntiTheist            0.0077676768 0.0033391579 0.0037837229
# AntiWhiteness         0.0000000000 0.0032847332 0.1881447307
# Conspiracy            0.0000000000 0.0481664049 0.0643282156
# Educational           0.0000067955 0.0005785647 0.0157219683
# LateNightTalkShow     0.0000000000 0.0000000000 0.1828102472
# Libertarian           0.0000000000 0.0058575645 0.1221823961
# MRA                   0.0000000000 0.0848448284 0.0806314604
# Mainstream News       0.0000000000 0.0388304592 0.3408730503
# ManoelAltLite         0.0000000000 0.0022516879 0.1182210565
# ManoelAltRight        0.0000000000 0.0049201709 0.1102633139
# MissingLinkMedia      0.0000000000 0.0007351420 0.0738199519
# PartisanLeft          0.0007874967 0.0009375389 0.3230812284
# PartisanRight         0.0000000000 0.0082495561 0.1061921074
# Provocateur           0.0495292827 0.0104790207 0.0448014571
# ReligiousConservative 0.0000000000 0.0146083866 0.0824937220
# SocialJustice         0.0803217575 0.0070093772 0.0251915169
# Socialist             0.2267006038 0.0060339222 0.0051477722
# StateFunded           0.0000513115 0.2711561063 0.1912588358
# WhiteIdentitarian     0.0001004254 0.0479003316 0.0569210394
#
#                        WhiteIdentitarian
# AntiSJW                     0.0034810667
# AntiTheist                  0.0000000000
# AntiWhiteness               0.0000000000
# Conspiracy                  0.0000000000
# Educational                 0.0000000000
# LateNightTalkShow           0.0000000000
# Libertarian                 0.0000000000
# MRA                         0.0000000000
# Mainstream News             0.0000000000
# ManoelAltLite               0.0011376150
# ManoelAltRight              0.0304070443
# MissingLinkMedia            0.0000000000
# PartisanLeft                0.0000000000
# PartisanRight               0.0013699624
# Provocateur                 0.0026206051
# ReligiousConservative       0.0013019177
# SocialJustice               0.0000000000
# Socialist                   0.0000000000
# StateFunded                 0.0000000000
# WhiteIdentitarian           0.0794244513
#
# [20 rows x 24 columns]

# %%
#Markov Steady State Simulation
#matrix = pd.read_csv("Markov Matrix without Others.csv").drop(columns = "Unnamed: 0")
vec = np.zeros((len(markovmatrix),1))
vec[0:len(markovmatrix)] = 1/len(markovmatrix)

for _ in range(100):
    vec = np.dot(np.transpose(markovmatrix),vec)

probdf = pd.DataFrame(vec, index = ['PartisanRight','Conspiracy','PartisanLeft','SocialJustice',
 'Libertarian','AntiSJW', 'MissingLinkMedia','WhiteIdentitarian','AIN',
 'ManoelAltRight','MRA','ReligiousConservative','ManoelIDW','Provocateur',
 'ManoelAltLite','Socialist','Mainstream News','TV', 'AntiTheist', 'StateFunded',
 'Educational', 'LateNightTalkShow', 'Revolutionary', 'AntiWhiteness',
 'Politician'])
probdf = probdf.rename({0:"Steady State Probability"},axis = 1)
probdf
#probdf.to_csv("Steady State Probability without Others.csv")
# Out:
#                          Steady State Probability
# Alt-light                            0.0121494791
# Alt-right                            0.0000000000
# Anti-Theist                          0.0105913078
# Anti-white                           0.0000586406
# Conspiracy                           0.0133317371
# IDW                                  0.1590053198
# Libertarian                          0.0522580782
# MRA                                  0.0000017808
# Partisan Left                        0.1293940420
# Partisan Right                       0.0442894550
# Religious Conservative               0.0000000000
# Revolutionary Socialist              0.0016258228
# Social Justice                       0.5382034309
# Socialist                            0.0390909059

# %% [markdown]
# This model is scaled taking into accounts of video views, thus it shows what video types more people are exposed towards

# %%
uniquetags = ['PartisanRight','Conspiracy','PartisanLeft','SocialJustice',
 'Libertarian','AntiSJW', 'MissingLinkMedia','WhiteIdentitarian','AIN',
 'ManoelAltRight','MRA','ReligiousConservative','ManoelIDW','Provocateur',
 'ManoelAltLite','Socialist','Mainstream News','TV', 'AntiTheist', 'StateFunded',
 'Educational', 'LateNightTalkShow', 'Revolutionary', 'AntiWhiteness',
 'Politician']


temp = pd.read_csv("combined tags.csv").drop(columns = "Unnamed: 0")

for tag in uniquetags:
    if not (tag in temp["Category"].unique()):
        print(tag)
# Out:
# AIN
# ManoelIDW
# TV
# Revolutionary
# Politician

# %%
#temp[temp["Category"] == "Anti-white"]
