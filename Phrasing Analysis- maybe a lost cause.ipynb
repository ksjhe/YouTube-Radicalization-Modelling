# %%
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords

# %%
df = pd.read_csv("combined ideology.csv").drop(columns = "Unnamed: 0")

#formats string
df["Current Video"] = df["Current Video"].str.upper().str.replace('[^A-Za-z0-9 ]', '')


#splits the strings in each category and counts how many times a string pops up
temp =  df[df["Category"] == 'IDW']
df["Current Video"] = df["Current Video"].str.split(" ")


counter = {}


#counts strings and creates a data frame
for category in df["Category"].unique():
    
    for string in strings:
        for substr in string:
            try:
                counter[category]
            except:
                counter[category] = {}
            try:
                counter[category][substr] += 1
            except:
                counter[category][substr] = 1

#pd.DataFrame(counter)
df.groupby(["Category","Current Video"]).agg({"Count":"first"})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-220-30a52f283321> in <module>
#      28
#      29 #pd.DataFrame(counter)
# ---> 30 df.groupby(["Category","Current Video"]).agg({"Count":"first"})
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, *args, **kwargs)
#     938         func = _maybe_mangle_lambdas(func)
#     939
# --> 940         result, how = self._aggregate(func, *args, **kwargs)
#     941         if how is None:
#     942             return result
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\base.py in _aggregate(self, arg, *args, **kwargs)
#     426
#     427                 try:
# --> 428                     result = _agg(arg, _agg_1dim)
#     429                 except SpecificationError:
#     430
#
# ...

# %%
words = [i.upper() for i in stopwords.words("english")]
strdf[~strdf["Word"].isin(words)][strdf["Frequency"] >= 5]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#                      Ideology      Word  Frequency
# 5                   Alt-light                   35
# 19                  Alt-light    JORDAN         15
# 21                  Alt-light  PETERSON         15
# 186                 Alt-light        VS          8
# 515                 Alt-right                   35
# 529                 Alt-right    JORDAN         15
# 531                 Alt-right  PETERSON         15
# 696                 Alt-right        VS          8
# 1025              Anti-Theist                   35
# 1039              Anti-Theist    JORDAN         15
# 1041              Anti-Theist  PETERSON         15
# 1206              Anti-Theist        VS          8
# 1535               Anti-white                   35
# 1549               Anti-white    JORDAN         15
# 1551               Anti-white  PETERSON         15
# ...
