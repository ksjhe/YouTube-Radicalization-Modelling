# %%
library(tidyverse)
library(reshape2)
options(scipen = 999)
# Out:
# Warning message:
# "package 'reshape2' was built under R version 3.6.3"
# Attaching package: 'reshape2'
#
# The following object is masked from 'package:tidyr':
#
#     smiths

# %%
#sets up the nessesary categories
df <- read_csv("combined tags.csv", col_types = cols(
  X1 = col_double(),
  Category = col_factor(),
  `Current Channel` = col_factor(),
  `Current Video` = col_factor(),
  `Current Views` = col_double(),
  `Next Channel` = col_factor(),
  Count = col_double(),
  CHANNEL_TITLE = col_factor(),
  TAGS = col_character()
)) %>% select(-`X1`) %>% rename(c("Next Tag" = TAGS,"Current Tag" = Category))


head(df)
# Out:
# Warning message:
# "Missing column names filled in: 'X1' [1]"
#   Current Tag   Current Channel Current Video              Current Views
# 1 PartisanRight Michael Knowles Too Few Problems | Ep. 549 10897
# 2 PartisanRight Michael Knowles Too Few Problems | Ep. 549 10897
# 3 PartisanRight Michael Knowles Too Few Problems | Ep. 549 10897
# 4 PartisanRight Michael Knowles Too Few Problems | Ep. 549 10897
# 5 PartisanRight Michael Knowles Too Few Problems | Ep. 549 10897
# 6 PartisanRight Michael Knowles Too Few Problems | Ep. 549 10897
#   Next Channel        Count CHANNEL_TITLE     Next Tag
# 1 Michael Knowles     4     Michael Knowles   PartisanRight
# 2 Lewis Howes         1     NA                Others
# 3 PatrickCoffin.media 1     NA                Others
# 4 YAFTV               2     YAFTV             ReligiousConservative
# 5 HooverInstitution   1     HooverInstitution Libertarian
# 6 The New School      1     NA                Others

# %%
#sets up impressions: (views)(recommendations)/recommendations sampled
df <- df %>% group_by(`Current Video`) %>% mutate(total = sum(Count)) %>% mutate(Impressions = `Current Views` * Count/total) %>% select(-total)
df
# Out:
# Warning message:
# "Factor `Current Video` contains implicit NA, consider using `forcats::fct_explicit_na`"Warning message:
# "Factor `Current Video` contains implicit NA, consider using `forcats::fct_explicit_na`"Warning message:
# "Factor `Current Video` contains implicit NA, consider using `forcats::fct_explicit_na`"Warning message:
# "Factor `Current Video` contains implicit NA, consider using `forcats::fct_explicit_na`"Warning message:
# "Factor `Current Video` contains implicit NA, consider using `forcats::fct_explicit_na`"Warning message:
# "Factor `Current Video` contains implicit NA, consider using `forcats::fct_explicit_na`"
#       Current Tag   Current Channel
# 1     PartisanRight Michael Knowles
# 2     PartisanRight Michael Knowles
# 3     PartisanRight Michael Knowles
# 4     PartisanRight Michael Knowles
# 5     PartisanRight Michael Knowles
# 6     PartisanRight Michael Knowles
# 7     PartisanRight ThePatriotNurse
# 8     PartisanRight ThePatriotNurse
# 9     PartisanRight ThePatriotNurse
# 10    PartisanRight ThePatriotNurse
# 11    PartisanRight ThePatriotNurse
# 12    PartisanRight ThePatriotNurse
# 13    PartisanRight ThePatriotNurse
# 14    PartisanRight ThePatriotNurse
# 15    PartisanRight pocketsofthefuture
# 16    PartisanRight pocketsofthefuture
# 17    PartisanRight pocketsofthefuture
# 18    PartisanRight pocketsofthefuture
# 19    PartisanRight pocketsofthefuture
# 20    PartisanRight pocketsofthefuture
# 21    PartisanRight Adam Carolla
# 24    The Next News Network                Conspiracy              654.4
# 25    NA                                   Others                  654.4
# 26    Fox News                             Mainstream News        3926.4
# 27    LastWeekTonight                      TV                      654.4
# 28    CNN                                  TV                      654.4
# 29    Dr. Edward Dutton: The Jolly Heretic PartisanRight          2957.2
# 30    NA                                   Others                 1478.6
# ...   ...                                  ...                   ...
# 14926 NA                                   Others                1490.400
# 14927 NA                                   Others                1490.400
# 14928 Fox News                             TV                    4471.200
# 14929 NBC News                             PartisanLeft          1490.400
# 14930 The View                             TV                    1490.400
# 14931 African Diaspora News Channel        AntiWhiteness         3341.800
# 14932 NA                                   Others                3341.800
# 14933 NA                                   Others                3341.800
# 14934 Fox News                             PartisanRight         6683.600
# 14935 MSNBC                                PartisanLeft          6683.600
# 14936 NA                                   Others                3341.800
# 14937 NA                                   Others                3341.800
# 14938 Roland S. Martin                     SocialJustice         3341.800
# 14939 ReyRoSho                             AntiWhiteness         6590.400
# 14940 NA                                   Others                6590.400
# 14941 NA                                   Others                3295.200
# 14942 NA                                   Others                3295.200
# 14943 NA                                   Others                3295.200
# 14944 NA                                   Others                3295.200
# 14945 Fox News                             PartisanRight         3295.200
# 14946 NA                                   Others                3295.200
# 14947 African Diaspora News Channel        SocialJustice         2793.333
# 14948 NA                                   Others                2793.333
# 14949 NA                                   Others                2793.333
# 14950 NA                                   Others                2793.333
# 14951 NowThis News                         SocialJustice         2793.333
# 14952 NA                                   Others                5586.667
# 14953 The View                             PartisanLeft          2793.333
# 14954 NA                                   Others                      NA
# 14955 MSNBC                                PartisanLeft          2793.333

# %%
# Amount of channels sampled per tag
channelsample <- df %>% group_by(`Current Tag`,`Current Channel`) %>%
summarize() %>% ungroup() %>% mutate(temp = 1) %>% group_by(`Current Tag`) %>%
summarize(`Channels Sampled`= sum(temp)) %>% filter(!is.na(`Current Tag`))
# Out:
# Warning message:
# "Factor `Current Tag` contains implicit NA, consider using `forcats::fct_explicit_na`"Warning message:
# "Factor `Current Channel` contains implicit NA, consider using `forcats::fct_explicit_na`"Warning message:
# "Factor `Current Tag` contains implicit NA, consider using `forcats::fct_explicit_na`"

# %%
#number of videos sampled per channel
vidsample <- df %>% group_by(`Current Tag`,`Current Video`) %>% summarize() %>% ungroup() %>%
mutate(temp = 1) %>% group_by(`Current Tag`) %>% summarize(`Videos Sampled` = sum(temp)) %>% filter(!is.na(`Current Tag`))

channelsample %>% left_join(vidsample)
# Out:
# Warning message:
# "Factor `Current Tag` contains implicit NA, consider using `forcats::fct_explicit_na`"Warning message:
# "Factor `Current Video` contains implicit NA, consider using `forcats::fct_explicit_na`"Warning message:
# "Factor `Current Tag` contains implicit NA, consider using `forcats::fct_explicit_na`"Joining, by = "Current Tag"
#    Current Tag           Channels Sampled Videos Sampled
# 1  PartisanRight         60                99
# 2  Conspiracy            54               100
# 3  PartisanLeft          53               100
# 4  SocialJustice         60               100
# 5  Libertarian           33               100
# 6  AntiSJW               57               100
# 7  MissingLinkMedia      31               100
# 8  WhiteIdentitarian     30                94
# 9  ManoelAltRight        18                86
# 10 MRA                   18               100
# 11 ReligiousConservative 44               100
# 12 Provocateur           18                97
# 13 ManoelAltLite         49               100
# 14 Socialist             37               100
# 15 Mainstream News       35               100
# 16 AntiTheist            38               100
# 17 StateFunded           30               100
# 18 Educational           27               100
# 19 LateNightTalkShow      6               100
# 20 AntiWhiteness          2               100

# %%
#What do each Category send their most impressions to
df %>% filter(`Next Tag` != "Others") %>% group_by(`Current Tag`,`Next Tag`) %>% summarize( Impressions = sum(`Impressions`)) %>%
filter(Impressions == max(Impressions), !is.na(`Current Tag`)) %>% 
select(`Current Tag`, `Next Tag`, `Impressions`) %>% arrange(desc(Impressions))
# Out:
#    Current Tag           Next Tag         Impressions
# 1  LateNightTalkShow     SocialJustice    38240086.8
# 2  Educational           Educational      16035955.4
# 3  SocialJustice         SocialJustice    11856587.4
# 4  PartisanLeft          PartisanLeft     11319986.9
# 5  AntiTheist            AntiTheist        3567087.1
# 6  AntiSJW               Conspiracy        3431109.0
# 7  Mainstream News       Mainstream News   3115057.7
# 8  ManoelAltLite         PartisanRight     1845211.2
# 9  MissingLinkMedia      MissingLinkMedia  1589972.7
# 10 Libertarian           Libertarian       1558393.0
# 11 PartisanRight         PartisanRight     1423211.3
# 12 Conspiracy            PartisanRight     1360346.6
# 13 Socialist             SocialJustice     1275081.8
# 14 WhiteIdentitarian     Libertarian       1256907.5
# 15 Provocateur           AntiSJW            997949.5
# 16 ManoelAltRight        Libertarian        889470.1
# 17 ReligiousConservative AntiSJW            620194.8
# 18 AntiWhiteness         AntiWhiteness      400169.2
# 19 StateFunded           Mainstream News    263007.5
# 20 MRA                   AntiSJW            228825.3

# %%
#tags back to itself

# %%
#average views for each category - LATENIGHTTALKSHOW
views <- df %>% group_by(`Current Tag`,`Current Video`,`Current Views`) %>% summarize() %>% filter(!is.na(`Current Views`))
views %>% ggplot(aes(x=`Current Tag`, y = `Current Views`, color = `Current Tag`)) + geom_point() + geom_boxplot() + coord_flip()
# Out:
# Warning message:
# "Factor `Current Tag` contains implicit NA, consider using `forcats::fct_explicit_na`"Warning message:
# "Factor `Current Video` contains implicit NA, consider using `forcats::fct_explicit_na`"
# plot without title

# %%
#average views for each category - NO LATENIGHTTALKSHOW
views %>% ggplot(aes(x=`Current Tag`, y = `Current Views`, color = `Current Tag`)) + geom_point() +
geom_boxplot() + coord_flip() + ylim(0,1000000)
# Out:
# Warning message:
# "Removed 77 rows containing non-finite values (stat_boxplot)."Warning message:
# "Removed 77 rows containing missing values (geom_point)."
# plot without title

# %%
#distribution of sent impressionss
df %>%
# Out:
# Warning message:
# "Factor `Current Video` contains implicit NA, consider using `forcats::fct_explicit_na`"Warning message:
# "Factor `Current Video` contains implicit NA, consider using `forcats::fct_explicit_na`"Warning message:
# "Factor `Current Video` contains implicit NA, consider using `forcats::fct_explicit_na`"
#       Current Tag   Current Channel
# 1     PartisanRight Michael Knowles
# 2     PartisanRight Michael Knowles
# 3     PartisanRight Michael Knowles
# 4     PartisanRight Michael Knowles
# 5     PartisanRight Michael Knowles
# 6     PartisanRight Michael Knowles
# 7     PartisanRight ThePatriotNurse
# 8     PartisanRight ThePatriotNurse
# 9     PartisanRight ThePatriotNurse
# 10    PartisanRight ThePatriotNurse
# 11    PartisanRight ThePatriotNurse
# 12    PartisanRight ThePatriotNurse
# 13    PartisanRight ThePatriotNurse
# 14    PartisanRight ThePatriotNurse
# 15    PartisanRight pocketsofthefuture
# 16    PartisanRight pocketsofthefuture
# 17    PartisanRight pocketsofthefuture
# 18    PartisanRight pocketsofthefuture
# 19    PartisanRight pocketsofthefuture
# 20    PartisanRight pocketsofthefuture
# 21    PartisanRight Adam Carolla
# 22    PartisanRight Adam Carolla
# 23    PartisanRight Adam Carolla
# 24    PartisanRight The Next News Network
# 25    PartisanRight The Next News Network
# 26    PartisanRight The Next News Network
# 27    PartisanRight The Next News Network
# 28    PartisanRight The Next News Network
# 29    PartisanRight Dr. Edward Dutton: The Jolly Heretic
# 30    PartisanRight Dr. Edward Dutton: The Jolly Heretic
# ...   ...           ...
# 14926 AntiWhiteness African Diaspora News Channel
# 14927 AntiWhiteness African Diaspora News Channel
# 14928 AntiWhiteness African Diaspora News Channel
# 14929 AntiWhiteness African Diaspora News Channel
# 14930 AntiWhiteness African Diaspora News Channel
# 14931 AntiWhiteness African Diaspora News Channel
# 14932 AntiWhiteness African Diaspora News Channel
# 14933 AntiWhiteness African Diaspora News Channel
# 14934 AntiWhiteness African Diaspora News Channel
# 14935 AntiWhiteness African Diaspora News Channel
# 14936 AntiWhiteness African Diaspora News Channel
# 14937 AntiWhiteness African Diaspora News Channel
# 14938 AntiWhiteness African Diaspora News Channel
# 14939 AntiWhiteness ReyRoSho
# 14940 AntiWhiteness ReyRoSho
# 14941 AntiWhiteness ReyRoSho
# 14942 AntiWhiteness ReyRoSho
# 14943 AntiWhiteness ReyRoSho
# 14944 AntiWhiteness ReyRoSho
# 14945 AntiWhiteness ReyRoSho
# 14946 AntiWhiteness ReyRoSho
# 14947 AntiWhiteness African Diaspora News Channel
# 14948 AntiWhiteness African Diaspora News Channel
# 14949 AntiWhiteness African Diaspora News Channel
# 14950 AntiWhiteness African Diaspora News Channel
# 14951 AntiWhiteness African Diaspora News Channel
# 14952 AntiWhiteness African Diaspora News Channel
# 14953 AntiWhiteness African Diaspora News Channel
# 14954 NA            NA
# 14955 AntiWhiteness African Diaspora News Channel
#       Current Video
# 1     Too Few Problems | Ep. 549
# 2     Too Few Problems | Ep. 549
# 3     Too Few Problems | Ep. 549
# 4     Too Few Problems | Ep. 549
# 5     Too Few Problems | Ep. 549
# 6     Too Few Problems | Ep. 549
# 7     Anti-Cancer, Immune Boosters...in the WOODS!
# 8     Anti-Cancer, Immune Boosters...in the WOODS!
# 9     Anti-Cancer, Immune Boosters...in the WOODS!
# 10    Anti-Cancer, Immune Boosters...in the WOODS!
# 11    Anti-Cancer, Immune Boosters...in the WOODS!
# 12    Anti-Cancer, Immune Boosters...in the WOODS!
# 13    Anti-Cancer, Immune Boosters...in the WOODS!
# 14    Anti-Cancer, Immune Boosters...in the WOODS!
# 10    NA                                   Others                 3460.3
# 11    NA                                   Others                 3460.3
# 12    NA                                   Others                 3460.3
# 13    NA                                   Others                 3460.3
# 14    NA                                   Others                 3460.3
# 15    pocketsofthefuture                   PartisanRight           502.2
# 16    Fox News                             Mainstream News        1004.4
# 17    NA                                   Others                  251.1
# 18    Jordan B Peterson                    ManoelIDW               251.1
# 19    NA                                   Others                  251.1
# 20    NA                                   Others                  251.1
# 21    Adam Carolla                         PartisanRight          6316.8
# 22    Late Night with Seth Meyers          PartisanLeft            902.4
# 23    PowerfulJRE                          AntiSJW                1804.8
# 24    The Next News Network                Conspiracy              654.4
# 25    NA                                   Others                  654.4
# 26    Fox News                             Mainstream News        3926.4
# 27    LastWeekTonight                      TV                      654.4
# 28    CNN                                  TV                      654.4
# 29    Dr. Edward Dutton: The Jolly Heretic PartisanRight          2957.2
# 30    NA                                   Others                 1478.6
# ...   ...                                  ...                   ...
# 14926 NA                                   Others                1490.400
# 14927 NA                                   Others                1490.400
# 14928 Fox News                             TV                    4471.200
# 14929 NBC News                             PartisanLeft          1490.400
# 14930 The View                             TV                    1490.400
# 14931 African Diaspora News Channel        AntiWhiteness         3341.800
# 14932 NA                                   Others                3341.800
# 14933 NA                                   Others                3341.800
# 14934 Fox News                             PartisanRight         6683.600
# 14935 MSNBC                                PartisanLeft          6683.600
# 14936 NA                                   Others                3341.800
# 14937 NA                                   Others                3341.800
# 14938 Roland S. Martin                     SocialJustice         3341.800
# 14939 ReyRoSho                             AntiWhiteness         6590.400
# 14940 NA                                   Others                6590.400
# 14941 NA                                   Others                3295.200
# 14942 NA                                   Others                3295.200
# 14943 NA                                   Others                3295.200
# 14944 NA                                   Others                3295.200
# 14945 Fox News                             PartisanRight         3295.200
# 14946 NA                                   Others                3295.200
# 14947 African Diaspora News Channel        SocialJustice         2793.333
# 14948 NA                                   Others                2793.333
# 14949 NA                                   Others                2793.333
# 14950 NA                                   Others                2793.333
# 14951 NowThis News                         SocialJustice         2793.333
# 14952 NA                                   Others                5586.667
# 14953 The View                             PartisanLeft          2793.333
# 14954 NA                                   Others                      NA
# 14955 MSNBC                                PartisanLeft          2793.333

# %%
impressions <- df %>% filter(`Next Tag` != "Others") %>% group_by(`Current Tag`) %>% mutate(`Available Impressions` = sum(Impressions)) %>%
ungroup() %>% group_by(`Next Tag`) %>% mutate(`Recieved Impressions` = sum(Impressions)) %>% ungroup() %>%
filter(`Current Tag` == `Next Tag`) %>% select(`Current Tag`,`Available Impressions`,`Recieved Impressions`) %>%
unique() 

impressions %>% melt(vars = `Current Tag`) %>% 
ggplot(aes(x = reorder(`Current Tag`,`value`),y = value)) + geom_bar(aes(fill = variable), stat = "identity",
                                           position = position_dodge(width = 0.5)) +coord_flip()
# Out:
# Using Current Tag as id variables
# plot without title

# %%
impressions %>% mutate(Advantage = `Recieved Impressions` - `Available Impressions`) %>%
ggplot(aes(x= reorder(`Current Tag`,Advantage), y = Advantage)) + geom_bar(stat = "identity", aes(fill = `Current Tag`)) +
coord_flip() + xlab("Tags")
# Out:
# plot without title
