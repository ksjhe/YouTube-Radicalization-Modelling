# %%
from selenium import webdriver
import time
import pandas as pd
import random

# %%
url = "https://youtu.be/BHLBaOASC74"
driver = webdriver.Chrome()

# %%
size = 10
df = pd.DataFrame(columns = ["Current Channel","Current Video","Current Views","Recommended Channel","Recommended Video","Recommended Views","recommended URL"])

for i in range(size):
    #driver.implicitly_wait(5)
    driver.get(url)
    driver.maximize_window()
    time.sleep(5)    
    
    
    videos = driver.find_elements_by_class_name("style-scope ytd-compact-video-renderer")

    #Gathers the future links
    thumbnails = driver.find_elements_by_id("thumbnail")
    links = [thumb.get_attribute("href") for thumb in thumbnails]
    links.pop()
    j = 0
    for vid in videos:
        #current video analytics
        curr_vid = driver.find_element_by_xpath('//*[@id="container"]/h1/yt-formatted-string').text
        curr_channel = driver.find_element_by_xpath('//*[@id="text"]/a').text
        curr_views = driver.find_element_by_xpath('//*[@id="count"]/yt-view-count-renderer/span[1]').text.replace("views","")

        #next video analytics
        next_channel = vid.find_element_by_class_name("style-scope ytd-channel-name").text
        next_title = vid.find_element_by_xpath('.//*[@id="video-title"]').text
        next_views = vid.find_element_by_xpath('.//*[@id="metadata-line"]/span[1]').text.replace("views", "")


        data = [{"Current Channel":curr_channel,
                   "Current Video":curr_vid,
                   "Current Views":curr_views,
                   "Recommended Channel":next_channel,
                   "Recommended Video":next_title,
                   "Recommended Views":next_views,
                   "recommended URL":links[j]}]
        j += 1
        df = df.append(data,ignore_index=True)
    
    choice = random.choice(range(0,len(links)-1))
    url = links[choice]

# %%
df
# Out:
#     Current Channel                          Current Video Current Views  \
# 0             shane  Conspiracy Theories with Shane Dawson   47,746,170
# 1             shane  Conspiracy Theories with Shane Dawson   47,746,170
# 2             shane  Conspiracy Theories with Shane Dawson   47,746,170
# 3             shane  Conspiracy Theories with Shane Dawson   47,746,170
# 4             shane  Conspiracy Theories with Shane Dawson   47,746,170
# ..              ...                                    ...           ...
# 187    Morgan Adams     TRYING CRAZY BACK TO SCHOOL SNACKS    7,024,660
# 188    Morgan Adams     TRYING CRAZY BACK TO SCHOOL SNACKS    7,024,660
# 189    Morgan Adams     TRYING CRAZY BACK TO SCHOOL SNACKS    7,024,660
# 190    Morgan Adams     TRYING CRAZY BACK TO SCHOOL SNACKS    7,024,660
# 191    Morgan Adams     TRYING CRAZY BACK TO SCHOOL SNACKS    7,024,660
#
#     Recommended Channel                                  Recommended Video  \
# 0          ShaneGlossin  Conspiracy Theories: Warning Signs with Shane ...
# 1                 shane       Investigating Conspiracies with Shane Dawson
# 2                 shane                   MIND BLOWING CONSPIRACY THEORIES
# 3                 shane                 $20,000 FIRST CLASS AIRPLANE SEATS
# 4                 shane                          TRYING DUMB LIFE HACKS 16
# ..                  ...                                                ...
# 187               shane                           $10,000 HOTEL ROOM SUITE
# 188      Safiya Nygaard  Trying Products That Asked To Sponsor Me (Not ...
# 189        Morgan Adams                 24 Hours in my Brothers Panic Room
# 190               shane                          TRYING DUMB LIFE HACKS 16
# 191               shane                  $10,000 MAKEOVER (BEFORE & AFTER)
#
#     Recommended Views                              recommended URL
# 0                12M   https://www.youtube.com/watch?v=pn-Kxynk5cU
# 1                41M   https://www.youtube.com/watch?v=sNuKpwX6Tz4
# 2                36M   https://www.youtube.com/watch?v=_53cGxAUuDk
# 3                34M   https://www.youtube.com/watch?v=i-sW4PfSxwA
# 4               5.1M   https://www.youtube.com/watch?v=UYi5X1Cc9XA
# ..                ...                                          ...
# 187              22M   https://www.youtube.com/watch?v=o08t04SJeqU
# 188              10M   https://www.youtube.com/watch?v=cY4e0uvp7uI
# 189             5.7M   https://www.youtube.com/watch?v=Rg7KrWfXZVU
# 190             5.1M   https://www.youtube.com/watch?v=UYi5X1Cc9XA
# 191              20M   https://www.youtube.com/watch?v=nR9M_rsXfDs
#
# [192 rows x 7 columns]

# %%
df.to_csv("youtube_crawler")

# %%
driver.quit()
